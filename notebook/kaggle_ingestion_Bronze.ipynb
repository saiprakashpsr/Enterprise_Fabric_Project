# %%
import requests
import os
import zipfile
import io
# Out:
# StatementMeta(, 3eebebdf-35ce-4848-922b-16c76b59cadc, 3, Finished, Available, Finished, False)

# %%
KAGGLE_USERNAME = "saiprakashreddypalle"
KAGGLE_KEY = "KGAT_8b34fa97e1da7a048398dd039bca0d61"
DATASET = "olistbr/brazilian-ecommerce"
BRONZE_PATH = "/lakehouse/default/Files/bronze/raw"
os.makedirs(BRONZE_PATH, exist_ok=True)
url = f"https://www.kaggle.com/api/v1/datasets/download/{DATASET}"
response = requests.get(
    url,
    auth=(KAGGLE_USERNAME, KAGGLE_KEY),
    stream=True
)
# Out:
# StatementMeta(, 3eebebdf-35ce-4848-922b-16c76b59cadc, 4, Finished, Available, Finished, False)
